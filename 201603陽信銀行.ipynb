# %%
import requests
from bs4 import BeautifulSoup

for i in range(4,39):
    url='http://www.sunnybank.com.tw/qa_view.asp?qaid={}'.format(i)+'&qclsid=3&lmenuid=5&smenuid=86&qkeyword='
        
    res = requests.get(url)
    res.encoding = 'big5'
    soup = BeautifulSoup(res.text)

    #div = soup.select('.info_tit b ')
    div2 = soup.select('.info_tit td ')
    #for k in div:
       # ds = k.text.strip()
        #print ds
        

    for sunny in div2[1]:
        print sunny.text.strip()
# Out:
# Q.
# 什麼是「eATM」？
#
#
#
# A.
# 「eATM」就是虛擬網路自動櫃員機，不需要申請，只要擁有讀卡機，以「晶片金融卡＋讀卡機」，上網連結到陽信銀行「eATM」，即可執行轉帳、繳稅、繳費、變更密碼、查詢帳戶餘額、晶片卡交易紀錄、常用轉入帳號編輯等金融交易。「eATM」提供每日24小時、全年無休的服務，您不需出門，在家就可以享有安全又便利的ATM服務，歡迎多加利用。
# Q.
# 如何連結到「eATM」？
#
#
#
# A.
# 請登入本行網站首頁，點選「eATM」連結，或直接登入至https://eatm.esunnybank.com.tw，歡迎設定為「我的最愛」。
# Q.
# 我沒有晶片金融卡，該如何申請？
#
#
# A.
# 請親攜身分證件、存款印鑑、存摺至原開戶分行辦理。
# Q.
# 其他銀行發行的晶片金融卡，可以使用於「eATM」？
#
#
#
# A.
# 可以。
# 本服務不限陽信銀行發行的晶片金融卡，國內各金融機構發行的晶片金融卡都可於本網站使用。
# Q.
# 為什麼我的晶片金融卡不能執行轉帳？
#
#
#
# A.
# 晶片金融卡的轉帳功能（含非約定轉帳、約定轉帳），需向發卡銀行申請。如您的晶片金融卡無轉帳功能，請向您的發卡銀行申請。
# Q.
# 我可以使用「eATM」繳納信用卡、大哥大電話費、學雜費？
#
#
#
# A.
# 可以。
# 各類繳費帳單，只要是可以利用ATM轉帳繳款者，都可在「eATM」轉帳繳納。
# Q.
# 什麼是跨行轉帳？
#
#
# A.
# 凡轉出帳號或轉入帳號，任ㄧ方或兩者皆非陽信銀行帳戶，即是跨行轉帳。
# Q.
# 「eATM」只接受陽信銀行發送的讀卡機？
#
#
# A.
# 不是。
# 使用於eATM之讀卡機不限本行所發送，舉凡配合報稅「自然人憑證」使用之讀卡機，或其他銀行提供之讀卡機，均可於eATM使用，只要讀卡機符合微軟公司PC/SC規格、支援自然人憑證、晶片金融卡及通過EMV LEVEL 1 規格認證即可，您可至各電腦資訊賣場購買。
# Q.
# 我在國外也可以使用「eATM」？
#
#
#
#
#
# A.
# 可以。
# 請上網連結至https://eatm.esunnybank.com.tw即可使用本項便捷的服務。
# Q.
# ...

# %%
import requests
from bs4 import BeautifulSoup
url = 'https://eatm.esunnybank.com.tw/WebATM/Home/QA'
res = requests.get(url)
#res.encoding = 'big5'
soup = BeautifulSoup(res.text)

div = soup.select('tr')
for a in div:
    for s in a.select('td')[1:]:
        print s
    
#k=1
#for sunny in div:
 #   print '' .format(k)+sunny.text.strip()
#    k +=1


#for sunny in div.select('tbody tr')[1:-1]:
   # print 'https://eatm.esunnybank.com.tw/WebATM/Home/QA' + tr.select('td')[0]
    #['href'][2:]
# Out:
# <td><img alt="陽信銀行LOGO" src="/WebATM/Images/sunnybank_logo.png"/></td>
# <td></td>
# <td align="left" width="220"><div id="imgFlower" style="height: 62px; z-index:0; position:relative;"><img src="/WebATM/Images/sun_folwer.png"/></div></td>
# <td></td>
# <td align="left" width="220"><div id="imgFlower" style="height: 62px; z-index:0; position:relative;"><img src="/WebATM/Images/sun_folwer.png"/></div></td>
# <td align="left" class="tdHead">
# <table style="width: 100%">
# <tr>
# <td align="left" valign="middle" width="60%"><img src="/WebATM/Images/Login/L4_1.png" vspace="10"/></td>
# <td align="right" valign="bottom" width="40%"><div style="color: #0000ff">[ <a href="javascript:window.close();">關閉視窗</a> ]</div></td>
# </tr>
# </table>
# </td>
# <td align="left" valign="middle" width="60%"><img src="/WebATM/Images/Login/L4_1.png" vspace="10"/></td>
# <td align="right" valign="bottom" width="40%"><div style="color: #0000ff">[ <a href="javascript:window.close();">關閉視窗</a> ]</div></td>
# ...

# %%
for i in range(4,39):
    url='http://www.sunnybank.com.tw/qa_view.asp?qaid={}'.format(i)+'&qclsid=3&lmenuid=5&smenuid=86&qkeyword='
    print url
# Out:
# http://www.sunnybank.com.tw/qa_view.asp?qaid=4&qclsid=3&lmenuid=5&smenuid=86&qkeyword=
# http://www.sunnybank.com.tw/qa_view.asp?qaid=5&qclsid=3&lmenuid=5&smenuid=86&qkeyword=
# http://www.sunnybank.com.tw/qa_view.asp?qaid=6&qclsid=3&lmenuid=5&smenuid=86&qkeyword=
# http://www.sunnybank.com.tw/qa_view.asp?qaid=7&qclsid=3&lmenuid=5&smenuid=86&qkeyword=
# http://www.sunnybank.com.tw/qa_view.asp?qaid=8&qclsid=3&lmenuid=5&smenuid=86&qkeyword=
# http://www.sunnybank.com.tw/qa_view.asp?qaid=9&qclsid=3&lmenuid=5&smenuid=86&qkeyword=
# http://www.sunnybank.com.tw/qa_view.asp?qaid=10&qclsid=3&lmenuid=5&smenuid=86&qkeyword=
# http://www.sunnybank.com.tw/qa_view.asp?qaid=11&qclsid=3&lmenuid=5&smenuid=86&qkeyword=
# http://www.sunnybank.com.tw/qa_view.asp?qaid=12&qclsid=3&lmenuid=5&smenuid=86&qkeyword=
# http://www.sunnybank.com.tw/qa_view.asp?qaid=13&qclsid=3&lmenuid=5&smenuid=86&qkeyword=
# http://www.sunnybank.com.tw/qa_view.asp?qaid=14&qclsid=3&lmenuid=5&smenuid=86&qkeyword=
# ...
