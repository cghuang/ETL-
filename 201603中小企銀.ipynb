# %%
#一般網路銀行
import requests
from bs4 import BeautifulSoup
url = 'https://portal.tbb.com.tw/tbbportal/'
res = requests.get(url)
soup = BeautifulSoup(res.text)


div = soup.select('.QuestionLayout')



div2 = soup.select('.AnsLayout')

k=1
for land in div:
    print 'Q{} : '.format(k) + land.text.strip()
    k +=1

    
#k=1    
#for land2 in div2:
   # print 'A{} : '.format(k)
# print land2.text.strip()
   # k +=1

# %% [markdown]
# # 信用卡權益服務

# %%
#開卡程序
import requests
from bs4 import BeautifulSoup
url = 'https://www.tbb.com.tw/67fa633f14.html?'
res = requests.get(url)
soup = BeautifulSoup(res.text)


div = soup.select('.control_me')


k=1
for tbb in div:
    print tbb.text.strip().encode('latin')
k +=1
# Out:
# 常見問題
# 開卡程序
# ◎為確保您的權益，避免您的信用卡在郵遞過程中被冒領冒用，您的卡片（含新卡、換卡、補發卡）必須先經過開卡程序驗證您的個人資料後方能啟用。
# 信用卡開卡
# 語音服務：請依照依額度通知書或卡片上的貼紙內容順序執行。〈開卡專線：區域碼412-1111或412-6666 【六碼地區為411-111或41-6666】〉
# 人工開卡：請撥本行客服專線02-23577171或0800-01-7171。
# 得利Combo晶片卡
# 金融卡開卡：親領卡片的客戶可選擇臨櫃開卡或於ATM自己執行開卡。
# 信用卡開卡：與一般信用卡相同可選擇語音或人工方式開卡。
# ◎請您務必於收到卡片，核對您的基本資料無誤後，立即使用原子筆或油性簽字筆於卡片背面簽名欄上簽名
# ◎請妥善保管您的卡片，避免刮傷背面磁條或接近磁場（如微波爐、電冰箱、電磁爐、馬達）及高溫場所。
# ◎卡片限本人在有效期間內使用，不得讓與、轉借、提供擔保或以其他方式將信用卡占有轉讓予第三人或交其使用。
# ◎卡片若有毀損或其他原因不能使用時，請洽本行發卡單位辨理，本行將儘速您重製新卡及密碼。
# ◎使用自動化設備預借現金或進行其他交易，就其交易密碼或其他辨識持卡人同一性之方式，應予保密，不得告知第三人。

# %%
#如何掛失
import requests
from bs4 import BeautifulSoup
url = 'https://www.tbb.com.tw/925896ed14.html?'
res = requests.get(url)
soup = BeautifulSoup(res.text)


div = soup.select('.control_me')


k=1
for tbb in div:
    print tbb.text.strip().encode('latin')
k +=1
# Out:
# 常見問題
# 如何掛失
# ◎信用卡若不慎於國內遺失、被竊、被搶、詐取或其他遭第三人佔有之情形，應儘速辦理掛失通報。通報電話：02-23577171或0800-01-7171。
# ◎信用卡若不慎於國外遺失、請即向當地信用卡組織服務中心或代理機構辦理掛失，或撥回國內由本行竭誠為您服務。
# 本國財金公司24小時服務專線
# 1-800-244-0706(限美國地區)
# 800-886-1003 (限新加坡)
# 886-2-2632-4555 (掛失專用)
# 886-2-2632-4617 (掛失專用)
# VISA信用卡組織國際服務專線
# 0-080-1-444-123 (臺灣地區)（免費電話）
# VISA全球客戶服務中心電話
# MasterCard 信用卡組織國際服務專線
# 00801-10-3400 (臺灣地區) （免費電話）
# 1-800-307-7309 (限美加地區、免費電話)
# 001-800-307-7309 (限墨西哥、免費電話)
# 1800-120-113 (限澳洲、免費電話)
# 0800-96-4767 (限英國、免費電話)
# 0800-819-1040 (限德國、免費電話)
# 0800-990418 (限南非、免費電話)
# 800-1100-113 (限新加坡、免費電話)
# 800-966677 (限香港、免費電話)
# 800-870-866 (限義大利、免費電話)
# 00531-11-3886 (現日本、免費電話)
# 其他地區：1-314-542-7111(對方付費)�
#
# ��������� ※ 以上對方付費電話均須經由國際臺轉接
# 如本行認為必要時，應於收理掛失手續日起十日內通知持卡人，要求於受通知起三日內向當地警察機關報案或以書面補行通知本行。
# 卡片掛失時，持卡人未於掛失時表明不補發，本行將會重製新卡及新密碼給您，有效期限與原卡相同；得利晶片卡因同時具有金融卡的功能，掛失後請逕向原發卡行申請補發。
# 正卡遺失只需掛失正卡，附卡遺失只需掛失附卡。
# 得利Combo晶片卡掛失時，金融卡與信用卡同時失效。

# %%
#如何繳款
import requests
from bs4 import BeautifulSoup
url = 'https://www.tbb.com.tw/1c3292dc14.html?'
res = requests.get(url)
soup = BeautifulSoup(res.text)


div = soup.select('.control_me')


k=1
for tbb in div:
    print tbb.text.strip().encode('latin')
k +=1
# Out:
# 常見問題
# 如何繳款
# ◎每期應繳金額
# 應繳總金額＝上期未繳清餘額＋本期消費帳款(含預借現金及電話撥接費用等)＋循環利息＋違約金＋其他費用。
#
#  ������� ※ 應繳總金額不足新臺幣 1,000 元時，須連同其它應繳費用一次全數繳納。
#
# 最低繳款金額＝應繳總金額【當期新增交易金額�10%＋前期款項餘額�2%】(若交易金額超過信用消費額度則以信用消費額度為準)＋超過信用額度之全部消費金額＋其他應繳費用(如年費、手續費、利息、違約金、延滯息及掛失費等）。
#
#
# �������� ※ 最低應繳總金額不足新臺幣 1,000 元時，以 1,000元計，另加其它應繳費用。
# ◎繳款方式
# 自動轉帳扣繳：您可以利用本行全省各營業單位之存款帳戶，選擇以「全額」或「最低應繳金額」方式自動轉帳扣繳。
# 臨櫃繳款：請填妥本行寄發之信用卡交易明細暨繳款通知書後，至本行各營業單位繳付「最低應繳金額」以上之帳款。
# e-Bill全國繳費網繳款：您可利用e-Bill全國繳費網http://ebill.ba.org.tw並依網頁說明輸入相關資料後，完成轉帳繳款。
# 郵局繳款：請填妥本行寄發之信用卡交易明細暨繳款通知書後，至全省郵局繳付「最低應繳金額」以上之帳款，該筆帳款將於二個營業日入帳。
# 便利商店繳款：您可持帳單至『全家便利商店』繳款(免收手續費)，請自行勾選繳納【應繳總金額】或【最低應繳金額】(上限為2萬元)，你的帳款將於繳款後三個營業日入帳。
# 其他轉帳繳款：您可以利用本行「電話銀行」、「網路銀行」等方式轉帳扣繳。
# 自動櫃員機（ATM）轉帳繳款：
# 插入金融卡並輸入密碼。
# 選擇「轉帳」、「繳費」服務（提醒您，繳費此服務項目不限NT$3萬元限制）
# 輸入銀行代碼「050」
# 輸入「信用卡帳號」（共14碼）。
#
# ����������� ※ 個人卡 ==> 500 + 正卡持卡人身分證字號 共14碼
# ��������������� 註:英文字母須轉換成為數字，例如：A＝01、B＝02....以此類推。
# ����������� ※ 外僑人士 ==> 51 + 正卡持卡人居留證統一證號 共14碼
# � � � � � � � � 註:英文字母須轉換成為數字，例如：A＝01、B＝02....以此類推。
#
# ...

# %%
#用卡小常識
import requests
from bs4 import BeautifulSoup
url = 'https://www.tbb.com.tw/d39bcf2a14.html?'
res = requests.get(url)
soup = BeautifulSoup(res.text)


div = soup.select('.control_me')


k=1
for tbb in div:
    print tbb.text.encode('latin')
k +=1
# Out:
# 常見問題
#
#
# 用卡小常識
#
#
# ◎簽帳消費
#
#
#
# 無論國內外，您只要在貼有與您信用卡相同標誌的特約商店就可以持卡簽帳消費。
# 服務員為您刷卡並取得授權時，您應保持信用卡勿離開您的視線範圍。
# 簽帳單核對無誤後，請在簽名處簽上與您信用卡背面簽樣相同之簽名，並取回卡片及簽帳單收執聯。
# 未填妥金額或空白之簽帳單請勿隨意簽字；簽帳單因錯誤需要重寫或取消交易時，請務必注意每聯都 逐一更正或確實撕毀。
# 請保留簽帳單收執聯，以便與本行所寄信用卡交易明細暨繳款通知書核對。
# 基於保護您的權益，本行信用卡有每日最高消費金額及消 費次數的限制，若您刷卡消費超過每日限額或限次時，請告知特約商店逕電洽其所屬收單機構辦理人工授權。
#
#
#
# ◎郵購或電話購物
#
#
#
# 僅需提供您的卡號、卡片有效期限、姓名、地址等資料，並請保留訂購單或相關文件影本以便對帳。
# 國外郵購貨品，若因郵寄尚未收到貨品而信用卡交易明細暨繳款通知書卻已出現費用時，請先向郵購公司查詢送貨情形，若確定未曾簽收貨品，可洽請發卡單位協助處理。
#
#
#
# ◎當您需要退貨時，請向特約商店索取退款單收執聯作為證明。（惟退貨交易所產生之外幣匯差，仍需由您負擔）。
#
#
# ◎旅館訂房及退房
#
#
#
# 您可提供您的信用卡卡號，向旅館預訂房間，並請要求給予〝訂房確認碼〞( Reservation Confirmation Code ) 以便住房時核對。
# 若因故取消訂房，請向旅館取得〝取消代碼〞( Cancellation Code) 以備日後證明，但您若未於規定時間內通知取消訂房時 ，則可能需支付一天的住宿費。
# 結帳時請旅館服務人員結清冰箱飲料等消費，以免日後補收；若您臨時取消信用卡結帳，請記得索回原先住進旅館時即預刷的空白簽帳單並撕毀作廢。（註：一般住宿旅館時，旅館人員都會要求先刷一張空白簽帳單，退房結帳時，再於空白簽帳單上填寫金額請您簽名確認）。
#
#
#
# ◎您可提供您的信用卡卡號作為預訂機位證明，若需取消或變更行程，請向航空公司索取退款證明，以免日後糾紛。
#
#
# ◎租車時，租車公司人員要求出示信用卡，並刷卡預先收取租車 費用；當您還車時，務必索取消費明細，並確認金額，租車公司人員會在消費明細單上簽名，證明車已交還公司。
#
#
# ...

# %% [markdown]
# # 前置協商專區

# %%
import requests
from bs4 import BeautifulSoup
url = 'https://www.tbb.com.tw/5_8_5.html'
res = requests.get(url)
soup = BeautifulSoup(res.text)


div = soup.select('#mainContent')


k=1
for tbb in div:
    print tbb.text.strip().encode('latin')
k +=1
# Out:
# 前置協商專區
#
#
#
# Q1：我想瞭解消費者債務清理條例前置協商的問題可以問誰?
#
#
# A1：您可以向各金融機構前置協商服務專線諮詢，您也可以透過網路進入銀行公會、金管會及各金融機構的網站進行查詢。
#
#
#
# Q2：需不需要找代辦公司或債務整合公司申請前置協商?
#
#
#
# A2：不需要。金融機構只接受本人親自申請辦理。透過代辦公司或債務整合公司並不會獲得更好的條件，而且還要付高額的手續費。
#
#
#
# Q3：什麼是前置協商?前置協商的重要性為何?
#
#
#
# A3：消費者債務清理條例所規定的作業流程，第一階段就是前置協商。前置協商是債務人提出協商申請後，全部的債權金融機構依債務人的償還能力與債務人共同擬定一個可行的償債方案，以解決債務問題。
#
#
#
# Q4：什麼債務可以進入前置協商?
#
#
#
# A4：您必須在金融機構有消費借貸、自用住宅借款、信用卡或現金卡債務之一，始得申請前置協商。
#
#
#
# Q5：前置協商的適用對象為何?
#
#
#
# A5：依據消費者債務清理條例規定，只要您是未曾參與前置協商、曾參與銀行公會協商機制協商未成立、5年內未從事營業活動、從事小規模營業活動營業額平均每月NT$20萬元以下之自然人，且有積欠金融機構債務者，都可申請前置協商。
#
#
#
# Q6：要先向債權金融機構申請「前置協商」後，才能向法院申請更生或清算?
#
#
#
# A6：是的，前置協商為聲請更生清算前之必要程序。
#
#
#
# Q7：我已參加銀行公會辦理之無擔保債務協商機制協商成立，是否可以再與銀行申請前置協商?
#
#
#
# A7：不可以，您並不符合申請前置協商之資格，建議您繼續依約繳款。
#
#
#
# Q8：如何申請前置協商?
#
#
#
# ...
