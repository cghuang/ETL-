# %%
import requests
from bs4 import BeautifulSoup
url = 'http://www.dbs.com.tw/treasures-zh/Footer/FAQ.page?pid=tw_tre_home_foot_FAQ_270115'
res = requests.get(url)
#res.encoding = 'big5'
soup = BeautifulSoup(res.text)


div = soup.select('tr')

#div2 = soup.select('ol')

k=1
for land in div:
    print format(k) + land.text.strip()
    k +=1

    
#k=1    
#for land2 in div2:
  #  print 'A{} : '.format(k)
#  print land2.text.strip()
   # k +=1
# Out:
# 1Q：網路銀行的服務時間是否有特別規定呢?
# 224小時服務項目：查詢類交易、台幣轉帳、台幣定存、個人資料變更、申請類、變更 密碼等。
# 【網路銀行基金交易服務時間】國內基金- 於週一至週五營業日09：00～15：30，視 為當日交易處理。境外基金- 於週一至週五營業日09：00～15：30，視為當日交易處理。 上述營業時間以外(15:30 〜 09:00)，視為次一營業日交易處理。
# 週一至週五營業日09:00~15:30：換匯交易
# 3Q：使用網路銀行是否安全？
# 4客戶的資料是非常安全的，因為本行之「簡訊動態密碼」，每次密碼皆不同，因此，從登 入開始到帳務交易，都有簡訊動態密碼為您把關，讓您不僅交易安全有保障，個人資料更 不會輕易被駭客竊取。此外，本行在資料傳輸過程中，使用 128 bits SSL encryption 封包傳送資料，就算有人 截到資料也無法解開或讀取資料。網路銀行系統所使用的為 https 作業，與 http 不同， 具有加密保護功能，客戶可以由瀏覽器上所顯示的訊息，來得知是否已經進入資料傳輸加 密保護模式，通常瀏覽器會出現一個已經上鎖的鎖頭，來表示目前所傳輸的資料，是經過 亂碼加密保護過的，以避免資料在傳輸過程中被竊取，因而發生流失的風險。
# 5Q：網路銀行所提供之服務有哪些？
# 6網路銀行提供您銀行服務、基金投資等帳務交易與查詢服務，主要功能導覽如下所列：主要功能導覽
#
# 帳戶總覽
# 帳務查詢
# 轉帳服務
# 定存服務
# 基金投資
# 個人資料變更
# 資料申請
# 7Q：我在任何時間、任何地點都能隨時登入並使用網路銀行服 務嗎？
# 8網路銀行一年365天、每天24小時，全年無休為您服務。只要手機訊號正常並收得到「簡訊 動態密碼」，以及網路所及之地，皆可使用網路銀行服務，省事又方便。
# 9Q：如何申請網路銀行服務？
# 101.臨櫃申請，請攜帶証明文件及原留印鑑至星展(台灣)任一分行辦理。
# 112.晶片讀卡機，請至本行網路銀行登入頁，點選「馬上申請」並選擇「使用晶片讀卡機」，依照指示操作即可輕鬆完成網路銀行註冊。＊僅適用已註冊動態簡訊密碼(SMS OTP)手機號碼者
# ...
